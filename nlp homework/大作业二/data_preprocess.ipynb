# %% [markdown]
# # Preprocessing of the corpus
# - `HIT-IRLab-Cilin_extended_full_2005.3.3.utf8.txt`
# - `Sense_POS.txt`
#
# See also `Cilin_process_guild.md`.

# %% [markdown]
# ## Cilin processing

# %%
cilin = open(r'./data/HIT-IRLab-Cilin_extended_full_2005.3.3.utf8'
    r'.txt', 'r', encoding='utf-8')

t_syn_dict = {}
# Words with more than 1 senses
syn_dict = {}
# Sense : words
syn_sense = {}

for line in cilin:
    # Skip the empty line
    if (line == ''):
        continue
    # Split the text by [space]
    sep = line.strip().split(' ')
    # Skip if not the synonym
    if (not sep[0].endswith('=')):
        continue
    # Read the type and the words
    sense, words = sep[0], sep[1:]
    # Trim the sense for each word from length of 8 to length
    # of 4 in order to align with the sense format of `Sense_POS.txt`
    sense = sense[0:4]

    # Everytime a new sense come in, update the `syn_sense`
    if (sense in syn_sense):
        for word in words:
            if (syn_sense[sense].count(word) == 0):
                syn_sense[sense].append(word)
    else:
        syn_sense[sense] = words

    # Iterate through the `words` with sense of `sense`,
    # and insert the sense into the dictionary respectively.
    for word in words:
        if (word in t_syn_dict):
            # Word has been added to the dictionary with 
            # different sense, so add the new sense to the 
            # word.
            if (t_syn_dict[word].count(sense) == 0):
                t_syn_dict[word].append(sense)
        else:
            # Word hasn't been found before, so we add it to 
            # the dictionary and create a sense list for it.
            t_syn_dict[word] = [sense]

for key in t_syn_dict:
    if (len(t_syn_dict[key]) > 1):
        syn_dict[key] = t_syn_dict[key]
cilin.close()

# %%
syn_dict
# Out:
# {'人': ['Aa01', 'Ab02', 'Dd17', 'De01', 'Dn03'],
#  '士': ['Aa01', 'Ab01', 'Ae10', 'Al01'],
#  '生人': ['Aa01', 'Aj02'],
#  '人口': ['Aa01', 'Dn03'],
#  '口': ['Aa01', 'Bk04', 'Bo09', 'Ca14', 'Dn03'],
#  '食指': ['Aa01', 'Bk08', 'Dn03'],
#  '劳力': ['Aa01', 'Dd14'],
#  '劳动力': ['Aa01', 'Dd14'],
#  '匹夫': ['Aa01', 'Al04'],
#  '个人': ['Aa01', 'Aa02', 'Ed55'],
#  '家伙': ['Aa01', 'Ba01', 'Bo01', 'Bo27'],
#  '东西': ['Aa01', 'Ba01', 'Da28'],
#  '货色': ['Aa01', 'Ba04'],
#  '崽子': ['Aa01', 'Bi01'],
#  '小子': ['Aa01', 'Aa02', 'Ab04', 'Ah14'],
#  '杂种': ['Aa01', 'Ah14'],
#  '畜生': ['Aa01', 'Bi01'],
#  '混蛋': ['Aa01', 'Ak03', 'Al04'],
#  '竖子': ['Aa01', 'Ab04', 'Af02'],
#  '鼠辈': ['Aa01', 'Ak03'],
#  '者': ['Aa01', 'Dd05', 'Ed61', 'Kd03', 'Kd04'],
#  '手': ['Aa01', 'Bk08', 'Fa06', 'Ka24'],
#  '匠': ['Aa01', 'Ae02'],
#  '客': ['Aa01', 'Ae09', 'Ag10', 'Aj05', 'Aj06', 'An07', 'Dn08', 'Ed61'],
#  '主': ['Aa01', 'Aj05', 'Df14', 'Ed56', 'Gb02', 'Ja04'],
#  '子': ['Aa01', 'Ab01', 'Ah14', 'Bh13', 'Bl05', 'Di17', 'Dj05', 'Eb36', 'Ed56'],
#  '家': ['Aa01', 'Ah08', 'Al02', 'Cb28', 'Di05', 'Di10', 'Dn08', 'Ed26'],
#  '夫': ['Aa01', 'Ah08', 'Ed61'],
#  '翁': ['Aa01', 'Ab02', 'Ah04', 'Ah07'],
#  '汉': ['Aa01', 'Ab01'],
#  '员': ['Aa01', 'Dn08'],
#  '分子': ['Aa01', 'Aj07'],
#  '鬼': ['Aa01', 'Dh01', 'Ed03'],
#  '货': ['Aa01', 'Ba04', 'He03'],
#  '棍': ['Aa01', 'Bb05', 'Bo13'],
#  '徒': ['Aa01', 'Aj10', 'Ed47', 'Ka07'],
#  '庶': ['Aa01', 'Ed59', 'Kc07'],
#  '老百姓': ['Aa01', 'Af11'],
#  '赤子': ['Aa01', 'Ab04'],
#  '萌': ['Aa01', 'Bh12', 'Dg03', 'Ib22', 'Ig01', 'Jd07'],
#  '众生': ['Aa01', 'Ba02'],
#  '人流': ['Aa01', 'Hg22'],
#  '大家': ['Aa01', 'Al02', 'Di05'],
#  '辈': ['Aa01', 'Dd16'],
#  '等': ['Aa01', 'Di16', 'Hi07', 'Jb01'],
#  '我': ['Aa02', 'Aa05'],
#  '余': ['Aa02', 'Ca05', 'Dn05', 'Ed30'],
#  '予': ['Aa02', 'Je05'],
#  '本人': ['Aa02', 'Aa05'],
#  '身': ['Aa02', 'Bc03', 'Bk01', 'Da17', 'Dn08'],
#  '人家': ['Aa02', 'Aa04', 'Aa05', 'Di05'],
#  '区区': ['Aa02', 'Eb01', 'Ed28'],
#  '仆': ['Aa02', 'Fd05'],
#  '鄙': ['Aa02', 'Ed26'],
#  '愚': ['Aa02', 'Ed26', 'Ee14', 'Hi55'],
#  '小人': ['Aa02', 'Af02', 'Ak03'],
#  '不肖': ['Aa02', 'Ee42'],
#  '老朽': ['Aa02', 'Ab02', 'Eb36'],
#  '老汉': ['Aa02', 'Ab02'],
#  '兄弟': ['Aa02', 'Aa03', 'Ah09'],
#  '妾': ['Aa02', 'Ah08'],
#  '朕': ['Aa02', 'Da22'],
#  '孤': ['Aa02', 'Ag03', 'Eb02', 'Ef05'],
#  '职': ['Aa02', 'Di15'],
#  '奴婢': ['Aa02', 'Af02'],
#  '奴才': ['Aa02', 'Af02', 'An05'],
#  '吾侪': ['Aa02', 'Dd16'],
#  '吾辈': ['Aa02', 'Dd16'],
#  '恁': ['Aa03', 'Ed61', 'Ka34'],
#  '而': ['Aa03', 'Kc02', 'Kc03', 'Kc08'],
#  '若': ['Aa03', 'Jb03', 'Kc08'],
#  '乃': ['Aa03', 'Ja01', 'Kc11'],
#  '君': ['Aa03', 'Ab01', 'Af05'],
#  '公': ['Aa03', 'Ah07', 'Da01', 'Di17', 'Eb35', 'Ed55', 'Ee40'],
#  '兄长': ['Aa03', 'Ah09'],
#  '大哥': ['Aa03', 'Ah09'],
#  '大嫂': ['Aa03', 'Ah12'],
#  '驾': ['Aa03', 'Bo21', 'Hf01'],
#  '陛下': ['Aa03', 'Af05'],
#  '主公': ['Aa03', 'Af05'],
#  '大王': ['Aa03', 'Af04', 'Af10', 'Al03'],
#  '他': ['Aa04', 'Ed61'],
#  '她': ['Aa04', 'Ba10'],
#  '彼': ['Aa04', 'Ed61'],
#  '其': ['Aa04', 'Ba10', 'Ed61'],
#  '渠': ['Aa04', 'Bn15'],
#  '自己': ['Aa05', 'Ed33'],
#  '自': ['Aa05', 'Ja05', 'Ka32', 'Kb02'],
#  '谁': ['Aa05', 'Aa06'],
#  '哪个': ['Aa05', 'Aa06'],
#  '哪位': ['Aa05', 'Aa06'],
#  '某': ['Aa05', 'Ed61'],
#  '男人': ['Ab01', 'Ah08'],
#  '汉子': ['Ab01', 'Ah08'],
#  '丈夫': ['Ab01', 'Ah08'],
#  '官人': ['Ab01', 'Ah08'],
#  '爷们': ['Ab01', 'Ah08'],
#  '先生': ['Ab01', 'Ae01', 'Ae13', 'Ae15', 'Ah08', 'Al01'],
#  '郎': ['Ab01', 'Ah08'],
#  '哥': ['Ab01', 'Ah09'],
#  '女人': ['Ab01', 'Ah08'],
#  '女性': ['Ab01', 'Eb35'],
#  '女儿': ['Ab01', 'Ah14'],
#  '女': ['Ab01', 'Ah14', 'Eb35'],
#  '娘': ['Ab01', 'Ah04'],
#  '妇': ['Ab01', 'Ah15'],
#  '妇道': ['Ab01', 'De01'],
#  '娘子军': ['Ab01', 'Ae10'],
#  '才女': ['Ab01', 'Al03'],
#  '娘儿们': ['Ab01', 'Ah08'],
#  '婆娘': ['Ab01', 'Ah08'],
#  '婆姨': ['Ab01', 'Ah08'],
#  '娘子': ['Ab01', 'Ah08'],
#  '姑娘': ['Ab01', 'Ah06', 'Ah13', 'Ah14'],
#  '丫头': ['Ab01', 'Ab04', 'Af02', 'Ah14'],
#  '千金': ['Ab01', 'Ah14'],
#  '闺女': ['Ab01', 'Ah14'],
#  '姑子': ['Ab01', 'Am01'],
#  '太太': ['Ab01', 'Ah08'],
#  '夫人': ['Ab01', 'Ah08'],
#  '奶奶': ['Ab01', 'Ab02', 'Ah02'],
#  '祸水': ['Ab01', 'Ak03'],
#  '男女': ['Ab01', 'Ah14'],
#  '儿女': ['Ab01', 'Ah14'],
#  '老人': ['Ab02', 'Ah04', 'Ai02'],
#  '老': ['Ab02',
#   'Da03',
#   'Eb24',
#   'Eb29',
#   'Eb36',
#   'Ec05',
#   'Ed51',
#   'Ee21',
#   'Ka01',
#   'Ka11'],
#  '长者': ['Ab02', 'Ai02', 'Ak03'],
#  '父': ['Ab02', 'Ah04'],
#  '老头子': ['Ab02', 'Ah08'],
#  '枯木朽株': ['Ab02', 'Dg02'],
#  '朽木粪土': ['Ab02', 'Al04'],
#  '寿星': ['Ab02', 'Bd01'],
#  '公公': ['Ab02', 'Af07', 'Ah02', 'Ah03', 'Ah07'],
#  '爷爷': ['Ab02', 'Ah02'],
#  '老爷爷': ['Ab02', 'Ah02'],
#  '老太爷': ['Ab02', 'Ah04'],
#  '老爹': ['Ab02', 'Ah02', 'Ah04'],
#  '老公公': ['Ab02', 'Af07', 'Ah07'],
#  '老爷子': ['Ab02', 'Ah04'],
#  '老人家': ['Ab02', 'Ah04'],
#  '丈人': ['Ab02', 'Ah07'],
#  '丈': ['Ab02', 'Hj29'],
#  '父老': ['Ab02', 'Ai02'],
#  '老奶奶': ['Ab02', 'Ah02'],
#  '老婆子': ['Ab02', 'Ah08'],
#  '老太太': ['Ab02', 'Ah04'],
#  '老婆婆': ['Ab02', 'Ah07'],
#  '姥姥': ['Ab02', 'Ae15', 'Ah03'],
#  '阿婆': ['Ab02', 'Ah07'],
#  '嬷嬷': ['Ab02', 'Af02'],
#  '大人': ['Ab02', 'Ah04'],
#  '丁': ['Ab02', 'Bb01', 'Dn03', 'Je13'],
#  '老小': ['Ab02', 'Ah01', 'Ah08'],
#  '大小': ['Ab02', 'Dd13'],
#  '大大小小': ['Ab02', 'Dd13'],
#  '青年': ['Ab03', 'Ca16'],
#  '后生': ['Ab03', 'Ai03', 'Eb36'],
#  '弟子': ['Ab03', 'Ae13'],
#  '子弟': ['Ab03', 'Ai03'],
#  '少年': ['Ab03', 'Ca15'],
#  '苗子': ['Ab03', 'Bh12', 'Da06', 'Da22', 'Dg03'],
#  '苗': ['Ab03', 'Bh12', 'Dg03'],
#  '龙驹': ['Ab03', 'Al03'],
#  '千里驹': ['Ab03', 'Al03', 'Bi06'],
#  '小儿': ['Ab04', 'Ah14', 'Ca15'],
#  '宝贝': ['Ab04', 'Ah14', 'Al04', 'Ba08', 'Dg01'],
#  '宝贝儿': ['Ab04', 'Ah14', 'Al04'],
#  '童稚': ['Ab04', 'Ca15'],
#  '孩子': ['Ab04', 'Ah14'],
#  '娃子': ['Ab04', 'Af01', 'Bi01'],
#  '幼': ['Ab04', 'Eb36'],
#  '童': ['Ab04', 'Eb06'],
#  '小': ['Ab04', 'Ah08', 'Ea03', 'Ea04', 'Eb25', 'Ed26', 'Ed38', 'Jb05', 'Ka05'],
#  '囡': ['Ab04', 'Ah14'],
#  '小不点儿': ['Ab04', 'Ea03'],
#  '妮子': ['Ab04', 'Af02'],
#  '细高挑儿': ['Ac01', 'Ea02'],
#  '骨头架子': ['Ac02', 'Bc03', 'Bk13', 'Ea07'],
#  '花': ['Ac03', 'Bb02', 'Bh02', 'Bh11', 'Dg01', 'Dl02', 'Ec06', 'He13'],
#  '佳人': ['Ac03', 'Al03'],
#  '仙人': ['Ac03', 'Dh01'],
#  '天仙': ['Ac03', 'Dh01'],
#  '仙子': ['Ac03', 'Dh01'],
#  '仙女': ['Ac03', 'Dh01'],
#  '嫦娥': ['Ac03', 'Bd02'],
#  '红颜': ['Ac03', 'Dc03'],
#  '婵娟': ['Ac03', 'Bd02', 'Eb30'],
#  '绝色': ['Ac03', 'Eb30'],
#  '倾国倾城': ['Ac03', 'Eb30'],
#  '天香国色': ['Ac03', 'Eb30'],
#  '国色天香': ['Ac03', 'Bh02', 'Eb30'],
#  '夜叉': ['Ac03', 'Ak04'],
#  '豁嘴': ['Ac03', 'Bk04'],
#  '豁子': ['Ac03', 'Cb21'],
#  '兔唇': ['Ac03', 'Bk04'],
#  '结巴': ['Ac03', 'Ib19'],
#  '结子': ['Ac03', 'Bp24'],
#  '华人': ['Ad01', 'Ad02'],
#  '同胞': ['Ad02', 'Ah09', 'Ed58'],
#  '外人': ['Ad02', 'Aj02'],
#  '外族': ['Ad02', 'Ad03', 'Di04'],
#  '老乡': ['Ad03', 'Ae07'],
#  '乡里': ['Ad03', 'Cb15'],
#  '邻里': ['Ad03', 'Aj02', 'Cb15'],
#  '文牍': ['Ae01', 'Dk16', 'Dk17'],
#  '文书': ['Ae01', 'Dk17'],
#  '总务': ['Ae01', 'Di19'],
#  '庶务': ['Ae01', 'Di19'],
#  '管事': ['Ae01', 'Ed47', 'Hc02'],
#  '帐房': ['Ae01', 'Di09'],
#  '经纪人': ['Ae01', 'Ae09'],
#  '中人': ['Ae01', 'Aj14', 'Al04'],
#  '伙计': ['Ae01', 'Ae06', 'Af02', 'Aj03'],
#  '工': ['Ae02', 'Di18', 'Ed09', 'Gc02'],
#  '工友': ['Ae02', 'Ae06'],
#  '艺人': ['Ae02', 'Ae17'],
#  '师傅': ['Ae02', 'Ae13', 'Aj10'],
#  '苦工': ['Ae02', 'Di19'],
#  '苦力': ['Ae02', 'Ae03'],
#  '雇工': ['Ae02', 'Af02', 'Hc26'],
#  '园丁': ['Ae02', 'Ae13'],
#  '画师': ['Ae02', 'Al01'],
#  '领港': ['Ae03', 'Hf04'],
#  '领江': ['Ae03', 'Hf04'],
#  '老大': ['Ae03', 'Dn04', 'Eb36', 'Ka01'],
#  '长年': ['Ae03', 'Eb24', 'Eb36'],
#  '水工': ['Ae03', 'Di18'],
#  '脚力': ['Ae03', 'Dd14', 'Dj07'],
#  '大师傅': ['Ae04', 'Am01'],
#  '生火': ['Ae04', 'Hj43'],
#  '绿衣使者': ['Ae05', 'Bi11'],
#  '通信员': ['Ae05', 'Ae10'],
#  '交通': ['Ae05', 'Id20'],
#  '门房': ['Ae05', 'Bn03'],
#  '传达': ['Ae05', 'Hi15'],
#  '侍者': ['Ae06', 'Af02'],
#  '酒家': ['Ae06', 'Dm04'],
#  '店家': ['Ae06', 'Af04', 'Dm04'],
#  '农家': ['Ae07', 'Di05'],
#  '屠夫': ['Ae08', 'An01'],
#  '贾': ['Ae09', 'He03', 'Hj21'],
#  '商': ['Ae09', 'Di18', 'Hi31'],
#  '市侩': ['Ae09', 'Ak06'],
#  '客人': ['Ae09', 'Ag10', 'Aj05', 'An07'],
#  '官长': ['Ae10', 'Af08'],
#  '帅': ['Ae10', 'Ed03'],
#  '麾下': ['Ae10', 'Aj08'],
#  '将军': ['Ae10', 'Bh08', 'Hh06'],
#  '将': ['Ae10', 'Hh06', 'Hj12', 'Ka13', 'Kb03', 'Kb05'],
#  '飞将军': ['Ae10', 'Ak02'],
#  '长官': ['Ae10', 'Af10'],
#  '警官': ['Ae10', 'Ae12'],
#  '武夫': ['Ae10', 'Ak02'],
#  '兵': ['Ae10', 'Bo27'],
#  '卒': ['Ae10', 'Ib03', 'Ka13'],
#  '老将': ['Ae10', 'Al02'],
#  '水师': ['Ae10', 'Di11'],
#  '水军': ['Ae10', 'Di11'],
#  '海军': ['Ae10', 'Di11'],
#  '探子': ['Ae10', 'Ae11'],
#  '便衣': ['Ae10', 'Bq03'],
#  '岗哨': ['Ae10', 'Cb28'],
#  '伞兵': ['Ae10', 'Di11'],
#  '空降兵': ['Ae10', 'Di11'],
#  '警卫': ['Ae10', 'Hb04'],
#  '护卫': ['Ae10', 'Hb04', 'Hi37'],
#  '红军': ['Ae10', 'Di11'],
#  '特': ['Ae11', 'Ed04', 'Ka07'],
#  '耳目': ['Ae11', 'Dk02'],
#  '警': ['Ae12', 'Da01'],
#  '侦探': ['Ae12', 'Hb09', 'Hc18'],
#  '看守': ['Ae12', 'Hb04'],
#  '刽子手': ['Ae12', 'An01'],
#  '师': ['Ae13', 'Aj10', 'Al02', 'Dd11', 'Di11', 'Ed60'],
#  '教练': ['Ae13', 'Hg06'],
#  '阿姨': ['Ae13', 'Af02', 'Ah06'],
#  '老夫子': ['Ae13', 'Af09', 'Al01'],
#  '夫子': ['Ae13', 'Ah08', 'Al01'],
#  '生': ['Ae13',
#   'Ae17',
#   'Al01',
#   'Da17',
#   'Da18',
#   'Eb15',
#   'Ed31',
#   'Ed51',
#   'Ee22',
#   'Hj43',
#   'Ib01',
#   'Ib03',
#   'Jd07',
#   'Ka01'],
#  '门下': ['Ae13', 'Af09'],
#  '受业': ['Ae13', 'Hg08'],
#  '学子': ['Ae13', 'Al01'],
#  '徒弟': ['Ae13', 'Aj10'],
#  '高足': ['Ae13', 'Bi06'],
#  '高才生': ['Ae13', 'Al03'],
#  '裁判': ['Ae14', 'Hc20', 'Hm06'],
#  '医': ['Ae15', 'Dk03', 'Hg20'],
#  '国医': ['Ae15', 'Dk03'],
#  '中医': ['Ae15', 'Dk03'],
#  '老娘': ['Ae15', 'Ah03', 'Ah04'],
#  '看护': ['Ae15', 'Hi37'],
#  '翻译': ['Ae16', 'Hg16'],
#  '通译': ['Ae16', 'Hg16'],
#  '编辑': ['Ae16', 'Hg17'],
#  '优': ['Ae17', 'Ed03'],
#  '星': ['Ae17', 'Bb02', 'Bd01'],
#  '伎': ['Ae17', 'Df09'],
#  '主角': ['Ae17', 'Al02'],
#  '外': ['Ae17', 'Cb05', 'Di02', 'Ed58', 'Ed61'],
#  '末': ['Ae17', 'Bb02', 'Bc01', 'Ca09', 'Da06'],
#  '青衣': ['Ae17', 'Af02'],
#  '正旦': ['Ae17', 'Ca25'],
#  '小丑': ['Ae17', 'Ak03'],
#  '丑': ['Ae17', 'Da01', 'Eb30', 'Ed41'],
#  '净': ['Ae17', 'Ef12', 'Ka06', 'Ka07'],
#  '仙姑': ['Ae18', 'Am01', 'Dh01'],
#  '无产阶级': ['Af01', 'Di06'],
#  '臧': ['Af01', 'Ee01'],
#  '差役': ['Af02', 'Af08'],
#  '繇': ['Af02', 'Dk27'],
#  '妈': ['Af02', 'Ah04'],
#  '奶子': ['Af02', 'Bk05'],
#  '跟脚': ['Af02', 'Ka13'],
#  '随从': ['Af02', 'Hj36'],
#  '左右': ['Af02', 'Cb06', 'Dn05', 'Hc10', 'Ka29'],
#  '地主': ['Af03', 'Aj05'],
#  '东家': ['Af03', 'Aj05'],
#  '老爷': ['Af03', 'Ah03'],
#  '财东': ['Af04', 'Ag04'],
#  '帝': ['Af05', 'Di08'],
#  '上': ['Af05',
#   'Ca04',
#   'Cb03',
#   'Dn05',
#   'Ed06',
#   'Ed57',
#   'Fa17',
#   'Fa20',
#   'Hg08',
#   'Hh01',
#   'Hi27',
#   'Hj62',
#   'Hj64',
#   'Hj67',
#   'Ih05',
#   'Jd03',
#   'Je12'],
#  '当今': ['Af05', 'Ca10'],
#  '皇上': ['Af05', 'Cb07'],
#  '娘娘': ['Af05', 'Dh01'],
#  '贵人': ['Af05', 'Af06'],
#  '皇室': ['Af06', 'Di05'],
#  '王室': ['Af06', 'Di05', 'Dm01'],
#  '皇家': ['Af06', 'Di05', 'Ed57'],
#  '金枝玉叶': ['Af06', 'Di05'],
#  '公爵': ['Af06', 'Di17'],
#  '万户侯': ['Af06', 'Di17'],
#  '显贵': ['Af06', 'Ed26'],
#  '显要': ['Af06', 'Ed26', 'Ed28'],
#  '官': ['Af08', 'Bk14', 'Ed45', 'Ed55'],
#  '官府': ['Af08', 'Dm01'],
#  '当道': ['Af08', 'Cb04', 'Ha03'],
#  '三朝元老': ['Af08', 'Al02'],
#  '鼎': ['Af08', 'Bp05'],
#  '青天': ['Af08', 'Cb07'],
#  '走卒': ['Af08', 'An05'],
#  '上相': ['Af09', 'Eb30'],
#  '相公': ['Af09', 'Ah08', 'Ah14', 'An07'],
#  '秀才': ['Af09', 'Al01'],
#  '生员': ['Af09', 'Al01'],
#  '师爷': ['Af09', 'Aj09'],
#  '使命': ['Af09', 'Di22'],
#  '使': ['Af09', 'Hc04', 'Hj28', 'Je04', 'Kc08'],
#  '行使': ['Af09', 'Hj28'],
#  '主脑': ['Af10', 'Dd09'],
#  '头脑': ['Af10', 'Db07', 'Df01'],
#  '魁首': ['Af10', 'Al03'],
#  '魁': ['Af10', 'Dn04'],
#  '主管': ['Af10', 'Hc09'],
#  '领队': ['Af10', 'Hc09'],
#  '名宿': ['Af11', 'Al01'],
#  '隐君子': ['Af11', 'An06'],
#  '好人': ['Ag01', 'Ak03', 'Ak04'],
#  '痴子': ['Ag01', 'Al04'],
#  '神经病': ['Ag01', 'Dl01'],
#  '残缺': ['Ag02', 'Eb07'],
#  '拐子': ['Ag02', 'An04'],
#  '驼背': ['Ag02', 'Ib20'],
#  '大肚子': ['Ag02', 'Ib09'],
#  '孤老': ['Ag03', 'An07'],
#  '独夫': ['Ag03', 'Ak03'],
#  '光杆儿': ['Ag03', 'Ef05'],
#  '孤家寡人': ['Ag03', 'Ef05'],
#  '大户': ['Ag04', 'An06', 'Di05'],
#  '豪富': ['Ag04', 'Di05'],
#  '财神': ['Ag04', 'Dh01'],
#  '寒士': ['Ag04', 'Al01'],
#  '乞': ['Ag04', 'Hj61'],
#  '宠儿': ['Ag05', 'Ah14'],
#  '叩头虫': ['Ag06', 'Bi18'],
#  '瓮中之鳖': ['Ag06', 'Ed07'],
#  '大头': ['Ag07', 'Dj05'],
#  '牺牲品': ['Ag07', 'Ba04'],
#  '垫脚石': ['Ag07', 'Dg07'],
#  '祸胎': ['Ag07', 'Da09', 'Db01'],
#  '祸根': ['Ag07', 'Da09', 'Db01'],
#  '祸端': ['Ag07', 'Da09', 'Db01'],
#  '火头': ['Ag07', 'Bg03', 'Df06'],
#  '逃犯': ['Ag08', 'An02'],
#  '亡命': ['Ag08', 'Hj06', 'Hj38'],
#  '浪人': ['Ag08', 'An04'],
#  '瘪三': ['Ag08', 'An03'],
#  '俘虏': ['Ag09', 'Hb14'],
#  '俘': ['Ag09', 'Hb14'],
#  '活口': ['Ag09', 'Aj14'],
#  '舌头': ['Ag09', 'Bk04'],
#  '囚': ['Ag09', 'An02', 'Hm04'],
#  '质': ['Ag09', 'Ba01', 'Ba03', 'Dd12', 'He09'],
#  '行者': ['Ag10', 'Am01'],
#  '行旅': ['Ag10', 'Hf04'],
#  '亲族': ['Ah01', 'Di05'],
#  '氏': ['Ah01', 'Dd15'],
#  '亲朋好友': ['Ah01', 'Aj01'],
#  '血亲': ['Ah01', 'Ed58'],
#  '骨肉': ['Ah01', 'Db10'],
#  '家室': ['Ah01', 'Ah08'],
#  '家口': ['Ah01', 'Dn03'],
#  '太公': ['Ah02', 'Ah04'],
#  '爷': ['Ah02', 'Ah04', 'Ai02'],
#  '爹爹': ['Ah02', 'Ah04'],
#  '阿爹': ['Ah02', 'Ah04'],
#  '婆婆': ['Ah02', 'Ah07'],
#  '家母': ['Ah03', 'Ah04'],
#  '大': ['Ah04', 'Ah05', 'Dj05', 'Ea03', 'Ec05', 'Ed26', 'Ed38', 'Jb04', 'Ka01'],
#  '先人': ['Ah04', 'Ai02'],
#  '母': ['Ah04', 'Eb35', 'Ed56'],
#  '妈妈': ['Ah04', 'An07'],
#  '姨娘': ['Ah04', 'Ah06', 'Ah08'],
#  '上下': ['Ah04', 'Dd04', 'Dn05'],
#  '上人': ['Ah04', 'Ai02', 'Am01'],
#  '伯父': ['Ah05', 'Ai02'],
#  '伯': ['Ah05', 'Di17', 'Dn04'],
#  '大伯': ['Ah05', 'Ai02'],
#  '大爷': ['Ah05', 'Ai02'],
#  '大妈': ['Ah05', 'Ai02'],
#  '大娘': ['Ah05', 'Ai02'],
#  '叔': ['Ah05', 'Ai02', 'Dn04'],
#  '叔叔': ['Ah05', 'Ai02'],
#  '堂叔': ['Ah05', 'Ai02'],
#  '婶': ['Ah05', 'Ah12'],
#  '姑': ['Ah06', 'Ah07', 'Ah13', 'Ka09'],
#  '舅': ['Ah06', 'Ah07', 'Ed58'],
#  '舅舅': ['Ah06', 'Ah13'],
#  '姑舅': ['Ah07', 'Ed58'],
#  '泰山': ['Ah07', 'Ak03'],
#  '岳': ['Ah07', 'Be04'],
#  '爱人': ['Ah08', 'Aj17'],
#  '女婿': ['Ah08', 'Ah15'],
#  '当家的': ['Ah08', 'Am01'],
#  '妻': ['Ah08', 'Hj51'],
#  '内': ['Ah08', 'Bk14', 'Ca06', 'Cb05', 'Da05', 'Ed58'],
#  '正房': ['Ah08', 'Bn03'],
#  '糟糠': ['Ah08', 'Br06'],
#  '续弦': ['Ah08', 'Hj51'],
#  '偶': ['Ah08', 'Eb02', 'Ka16'],
#  '哥儿': ['Ah09', 'Ah14'],
#  '雁行': ['Ah09', 'Dd07'],
#  '儿': ['Ah14', 'Dk05', 'Eb35'],
#  '男': ['Ah14', 'Di17', 'Eb35'],
#  '崽': ['Ah14', 'Bi01'],
#  '子嗣': ['Ah14', 'Ai03'],
#  '继嗣': ['Ah14', 'Hj10'],
#  '心肝': ['Ah14', 'Df02'],
#  '坦': ['Ah15', 'Ea11'],
#  '甥': ['Ah15', 'Ah16'],
#  '招女婿': ['Ah15', 'Hj51'],
#  '开山': ['Ai01', 'Hd17'],
#  '祖师': ['Ai01', 'Am01'],
#  '元老': ['Ai01', 'Ak03'],
#  '先行者': ['Ai01', 'Al05'],
#  '先辈': ['Ai01', 'Ai02', 'Dd16'],
#  '近人': ['Ai01', 'Aj02'],
#  '后人': ['Ai01', 'Ai03'],
#  '后代': ['Ai01', 'Ai03'],
#  '长辈': ['Ai02', 'Dd16'],
#  '长上': ['Ai02', 'Aj08'],
#  '前辈': ['Ai02', 'Dd16'],
#  '晚辈': ['Ai03', 'Dd16'],
#  '晚': ['Ai03', 'Ca09', 'Ca29', 'Eb22', 'Ed59'],
#  '小辈': ['Ai03', 'Dd16'],
#  '下辈': ['Ai03', 'Dd16'],
#  '后辈': ['Ai03', 'Dd16'],
#  '后进': ['Ai03', 'Ee37'],
#  '后': ['Ai03', 'Ca12', 'Cb04', 'Cb12', 'Ed59'],
#  '朋友': ['Aj01', 'Aj17'],
#  '友好': ['Aj01', 'Ed33'],
#  '交游': ['Aj01', 'Hi01'],
#  '相知': ['Aj01', 'Gb08'],
#  '知心人': ['Aj01', 'Aj02'],
#  '至交': ['Aj01', 'Db10'],
#  '忘年交': ['Aj01', 'Db10'],
#  '莫逆之交': ['Aj01', 'Db10'],
#  '旧交': ['Aj01', 'Db10'],
#  '旧': ['Aj01', 'Eb29', 'Ed51'],
#  '故交': ['Aj01', 'Db10'],
#  '校友': ['Aj01', 'Aj04'],
#  '对头': ['Aj01', 'Ed12', 'Ed49', 'Jc02'],
#  '冤家': ['Aj01', 'Aj17'],
#  '仇': ['Aj01', 'Da11'],
#  '敌': ['Aj01', 'Hb03', 'Jb01'],
#  '亲信': ['Aj02', 'Gb14'],
#  '腹心': ['Aj02', 'Df02'],
#  '伴': ['Aj03', 'Hi05'],
#  '搭档': ['Aj03', 'Hj12'],
#  '一行': ['Aj03', 'Dd07'],
#  '一起': ['Aj03', 'He16', 'Ka23'],
#  '同窗': ['Aj04', 'Jb01'],
#  '同班': ['Aj04', 'Jb01'],
#  '同事': ['Aj04', 'Hj11'],
#  '主人': ['Aj05', 'Aj11'],
#  '东': ['Aj05', 'Ca18', 'Cb02'],
#  '人马': ['Aj07', 'Di11'],
#  '队伍': ['Aj07', 'Di11'],
#  '徒子徒孙': ['Aj07', 'Aj10'],
#  '上面': ['Aj08', 'Cb03', 'Dd05'],
#  '上边': ['Aj08', 'Cb03'],
#  '上头': ['Aj08', 'Cb03', 'Dd05'],
#  '下面': ['Aj08', 'Cb03'],
#  '下头': ['Aj08', 'Cb03'],
#  '手底下': ['Aj08', 'Da21'],
#  '副': ['Aj09', 'Dn08', 'Ed28', 'Jc01'],
#  '下手': ['Aj09', 'Cb03', 'Hj12', 'Ig01'],
#  '臂助': ['Aj09', 'Hi36'],
#  '膀臂': ['Aj09', 'Bk08'],
#  '臂膀': ['Aj09', 'Bk08'],
#  '智囊': ['Aj09', 'Al04'],
#  '腰杆子': ['Aj09', 'Bk06'],
#  '支柱': ['Aj09', 'Al02', 'Bn06'],
#  '师父': ['Aj10', 'Am01'],
#  '代表': ['Aj13', 'Hi17', 'Ja03'],
#  '代办': ['Aj13', 'Hc01'],
#  '保': ['Aj14', 'Hb04', 'Jd01', 'Ka15'],
#  '中': ['Aj14',
#   'Ca06',
#   'Ca08',
#   'Cb04',
#   'Cb05',
#   'Da05',
#   'Ea03',
#   'Ed06',
#   'Ed47',
#   'Ie11',
#   'Je13'],
#  '对象': ['Aj17', 'Da28'],
#  '欢': ['Aj17', 'Da17', 'Ee09', 'Ga01'],
#  '相好': ['Aj17', 'Ed33', 'Gb09', 'Hi01'],
#  '王八': ['Aj17', 'An07', 'Bi15'],
#  '乌龟': ['Aj17', 'An07', 'Bi15'],
#  '英雄': ['Ak01', 'Ed20', 'Ee13'],
#  '豪杰': ['Ak01', 'Al03'],
#  '英豪': ['Ak01', 'Al03'],
#  '枭雄': ['Ak01', 'Ak03'],
#  '雄鹰': ['Ak01', 'Bi12'],
#  '豪客': ['Ak02', 'An03'],
#  '窝囊废': ['Ak02', 'Al04'],
#  '脓包': ['Ak02', 'Dl03'],
#  '狗熊': ['Ak02', 'Bi03'],
#  '良': ['Ak03', 'Ed03', 'Ka01'],
#  '圣': ['Ak03', 'Ed03', 'Ed57'],
#  '贤': ['Ak03', 'Ed26'],
#  '鲁殿灵光': ['Ak03', 'Jd01'],
#  '歹人': ['Ak03', 'An03'],
#  '禽兽': ['Ak03', 'Bi11'],
#  '残渣余孽': ['Ak03', 'Dg02'],
#  '势利小人': ['Ak03', 'Ak06'],
#  '光棍': ['Ak03', 'An04'],
#  '无赖': ['Ak03', 'An04', 'Ee38'],
#  '霸': ['Ak03', 'Hc10'],
#  '元凶': ['Ak03', 'An02'],
#  '豪强': ['Ak03', 'Ee38'],
#  '豪门': ['Ak03', 'Di05'],
#  '魔鬼': ['Ak03', 'Dh01'],
#  '魔王': ['Ak03', 'Dh01'],
#  '阎罗': ['Ak03', 'Dh01'],
#  '阎王': ['Ak03', 'Dh01'],
#  '鬼魔': ['Ak03', 'Dh01'],
#  '强暴': ['Ak03', 'Ee01', 'Ee38'],
#  '凶残': ['Ak03', 'Ee01'],
#  '奸邪': ['Ak03', 'Ee05'],
#  '奸佞': ['Ak03', 'Ee05'],
#  '菩萨': ['Ak04', 'Am01', 'Dh01'],
#  '凶神': ['Ak04', 'Dh01'],
#  '饕餮': ['Ak04', 'Ak12', 'Ib06'],
#  '凶神恶煞': ['Ak04', 'Dh01'],
#  '两面派': ['Ak05', 'Ee05'],
#  '滑头': ['Ak05', 'Ee16'],
#  '油嘴': ['Ak05', 'Ee16'],
#  '势利眼': ['Ak06', 'Ee05'],
#  '妖精': ['Ak08', 'Dh01'],
#  '狐狸精': ['Ak08', 'Dh01'],
#  '浪子': ['Ak09', 'An04'],
#  '骨董': ['Ak10', 'Ba03'],
#  '老古董': ['Ak10', 'Ba03', 'Eb29'],
#  '迂夫子': ['Ak10', 'Al01'],
#  '直性子': ['Ak11', 'Ee04'],
#  '直肠子': ['Ak11', 'Ee04'],
#  '大炮': ['Ak11', 'Bo27'],
#  '话匣子': ['Ak12', 'Bo04'],
#  '贫嘴': ['Ak12', 'Ee02'],
#  '尾巴': ['Ak12', 'Bc01', 'Bk09', 'Da15'],
#  '留声机': ['Ak12', 'Bo04'],
#  '夜猫子': ['Ak12', 'Bi11'],
#  '怪物': ['Ak12', 'Dh01'],
#  '斯文': ['Al01', 'Ee31'],
#  '学者': ['Al01', 'Al02'],
#  '大师': ['Al01', 'Al03', 'Am01'],
#  '宗师': ['Al01', 'Al03'],
#  '大手笔': ['Al01', 'Dk19'],
#  '内行': ['Al02', 'Ee22'],
#  '里手': ['Al02', 'Cb03'],
#  '好手': ['Al02', 'Al03'],
#  '把势': ['Al02', 'Dk30'],
#  '把式': ['Al02', 'Dk30'],
#  '通': ['Al02',
#   'Eb02',
#   'Ed09',
#   'Fa29',
#   'Gb08',
#   'Hf06',
#   'Hi15',
#   'Hn07',
#   'Id20',
#   'Ie02'],
#  '一把手': ['Al02', 'Al03'],
#  '大方': ['Al02', 'Cb07', 'Ee10', 'Ee31', 'Ee35'],
#  '骨干': ['Al02', 'Bk13', 'Ed28'],
#  '中坚': ['Al02', 'Ed28'],
#  '外行': ['Al02', 'Ee22'],
#  '英': ['Al03', 'Bh02'],
#  '俊秀': ['Al03', 'Eb30'],
#  '状元': ['Al03', 'Dn04'],
#  '高明': ['Al03', 'Ed03', 'Ee17'],
#  '尖子': ['Al03', 'Bc01'],
#  '超人': ['Al03', 'Ed04'],
#  '骥': ['Al03', 'Bi06'],
#  '人才': ['Al03', 'Dc03'],
#  '材': ['Al03', 'Ba06', 'Bp37', 'De04', 'Dk17'],
#  '材料': ['Al03', 'Ba06', 'Dk17'],
#  '奇才': ['Al03', 'De04'],
#  '天才': ['Al03', 'De04'],
#  '一表人材': ['Al03', 'Dc03'],
#  '干将': ['Al03', 'Bo29'],
#  '权威': ['Al03', 'Ed26'],
#  '上手': ['Al03', 'Cb03'],
#  '木头': ['Al04', 'Bm03'],
#  '废物': ['Al04', 'Ba08'],
#  '二五眼': ['Al04', 'Ed03'],
#  '凡庸': ['Al04', 'Ee17'],
#  '绣花枕头': ['Al04', 'Dg04'],
#  '半瓶醋': ['Al04', 'Ee18'],
#  '半吊子': ['Al04', 'Ee18'],
#  '马大哈': ['Al04', 'Ee14', 'Ee28'],
#  '模范': ['Al05', 'Dd11'],
#  '表率': ['Al05', 'Dd11'],
#  '榜样': ['Al05', 'Dd11'],
#  '师表': ['Al05', 'Dd11'],
#  '楷范': ['Al05', 'Dd11'],
#  '典型': ['Al05', 'Dd09', 'Dd11', 'Ed04'],
#  '先锋': ['Al05', 'Di11'],
#  '开路先锋': ['Al05', 'Di11'],
#  '佛': ['Am01', 'Dh01', 'Di12', 'Dk31', 'Ed57'],
#  '僧': ['Am01', 'Ed57'],
#  '法师': ['Am01', 'Am02'],
#  '老道': ['Am02', 'Ee21'],
#  '反革命': ['An01', 'Ee37'],
#  '反': ['An01', 'Ha01', 'Ha07', 'Ih02', 'Ka33'],
#  '匪徒': ['An01', 'An03'],
#  '黑社会': ['An01', 'Di10'],
#  '奸': ['An01', 'Ee05', 'Hn07'],
#  '逆': ['An01', 'Ee06', 'Ee37', 'Hi05'],
#  '叛逆': ['An01', 'Ee06', 'Ha07'],
#  '贼': ['An01', 'An03', 'Ee01'],
#  '主使': ['An02', 'Hi56'],
#  '盗': ['An03', 'Hn03'],
#  '寇': ['An03', 'Hb11'],
#  '匪': ['An03', 'Ka18'],
#  '胡子': ['An03', 'Bk12'],
#  '黄牛': ['An04', 'Hi04'],
#  '帮凶': ['An05', 'Hi60'],
#  '花魁': ['An07', 'Bh02'],
#  '神女': ['An07', 'Dh01'],
#  '野鸡': ['An07', 'Bi11', 'Ed45'],
#  '相帮': ['An07', 'Hi36'],
#  '物': ['Ba01', 'Da28'],
#  '玩意儿': ['Ba01', 'Bp35'],
#  '素': ['Ba01', 'Br06', 'Dd10', 'Ec04', 'Ec06', 'Ka10'],
#  '体': ['Ba01', 'Bc03', 'Bk01', 'Dk07'],
#  '整体': ['Ba01', 'Eb07'],
#  '结晶': ['Ba01', 'Da14'],
#  '水晶体': ['Ba01', 'Bk03'],
#  '晶状体': ['Ba01', 'Bk03'],
#  '抽样': ['Ba01', 'Hj25'],
#  '青': ['Ba02', 'Eb15', 'Ec02', 'Ec04'],
#  '品': ['Ba03', 'Di16', 'Hc20', 'Hh04', 'Hj45'],
#  '补给': ['Ba03', 'Ih05'],
#  '摆设': ['Ba03', 'Id08'],
#  '陈设': ['Ba03', 'Id08'],
#  '纪念': ['Ba03', 'Gb06'],
#  '奖': ['Ba03', 'Hc21'],
#  '零七八碎': ['Ba03', 'Eb07'],
#  '吉光片羽': ['Ba03', 'Ba08'],
#  '遗': ['Ba03', 'Hi26', 'Jd01'],
#  '信物': ['Ba03', 'Bp19', 'Db03'],
#  '当头': ['Ba03', 'Ka25'],
#  '当': ['Ba03',
#   'Bc01',
#   'Dm04',
#   'Ed49',
#   'Gb02',
#   'Gc03',
#   'He09',
#   'Hj24',
#   'Ja01',
#   'Jb01',
#   'Ka32',
#   'Kb01',
#   'Kf08'],
#  '活': ['Ba04', 'Di19', 'Ed14', 'Ee16', 'Hi36', 'Ib03'],
#  '新品': ['Ba04', 'Dd06'],
#  '出产': ['Ba04', 'Hd29'],
#  '土产': ['Ba04', 'Ed52'],
#  '器': ['Ba05', 'Bk14', 'Bo01', 'Gb21'],
#  '器械': ['Ba05', 'Bo27'],
#  '家什': ['Ba05', 'Bo01'],
#  '装置': ['Ba05', 'Hd02'],
#  '配备': ['Ba05', 'Hb01', 'Hc03'],
#  '装备': ['Ba05', 'Hb01'],
#  '料': ['Ba06', 'Br02', 'Dn08', 'Gb03'],
#  '香': ['Ba06', 'Ec07', 'Ec10', 'Ed16', 'Ed25'],
#  '柴米油盐': ['Ba06', 'Da17'],
#  '家电': ['Ba06', 'Bo01'],
#  '农机具': ['Ba06', 'Bo01'],
#  '礼': ['Ba07', 'Di13'],
#  '人情': ['Ba07', 'Da11', 'Da26', 'Db06', 'Df04', 'Df05', 'Di14'],
#  '人事': ['Ba07', 'Df07'],
#  '仪': ['Ba07', 'Bo18', 'Dc04', 'Di13'],
#  '赐': ['Ba07', 'Hi26'],
#  '贶': ['Ba07', 'Hi26'],
#  '妆': ['Ba07', 'Bp33'],
#  '供': ['Ba07', 'Dk11', 'Dk17', 'Hm02', 'Jc05'],
#  '宝物': ['Ba08', 'Dg01'],
#  '宝': ['Ba08', 'Dg01', 'Dk05', 'Ed26'],
#  '珍': ['Ba08', 'Ed27'],
#  '宝藏': ['Ba08', 'Dg01'],
#  '传家宝': ['Ba08', 'Dg01'],
#  '破烂': ['Ba08', 'Eb07'],
#  '滓': ['Ba08', 'Ef12'],
#  '矿': ['Ba08', 'Dm03'],
#  '担子': ['Ba09', 'Bo13', 'Di22'],
#  '担': ['Ba09', 'Dn08', 'Fa03', 'Hj24'],
#  '包裹': ['Ba09', 'Fa16'],
#  '包袱': ['Ba09', 'Di22'],
#  '包': ['Ba09', 'Dl04', 'Fa16', 'He04', 'Hj24', 'Id23', 'Jd05', 'Ka15'],
#  '卷': ['Ba09', 'Bb03', 'Br05', 'Dk17', 'Dn08', 'Fa16'],
#  '什么': ['Ba10', 'Ed61', 'Ka35', 'Ke03'],
#  '甚': ['Ba10', 'Ed61', 'Ka01'],
#  '啥': ['Ba10', 'Ed61'],
#  '哪': ['Ba10', 'Ka35', 'Kd03'],
#  '何': ['Ba10', 'Ed61', 'Ka35'],
#  '锭': ['Bb01', 'Bo03'],
#  '砖': ['Bb01', 'Bm06'],
#  '块': ['Bb01', 'Dl04', 'Dn08'],
#  '疙瘩': ['Bb01', 'Bp24', 'Da01', 'Da12', 'Dl04'],
#  '粉': ['Bb02', 'Bp32', 'Br06', 'Ec04', 'Hd03'],
#  '面': ['Bb02', 'Bc02', 'Bk02', 'Br01', 'Br05', 'Cb23', 'Dd05', 'Kb01'],
#  '面子': ['Bb02', 'Bc02', 'Da26'],
#  '霜': ['Bb02', 'Ec04'],
#  '沙': ['Bb02', 'Bm04', 'Eb16'],
#  '沙子': ['Bb02', 'Bm04'],
#  '点': ['Bb02',
#   'Bg09',
#   'Br09',
#   'Cb23',
#   'Dd05',
#   'Dk04',
#   'Fa34',
#   'Hc19',
#   'Hd20',
#   'Hg02',
#   'Hj43',
#   'Id18'],
#  '点子': ['Bb02', 'Bg07', 'Bg09', 'Db09', 'Dd09'],
#  '一点': ['Bb02', 'Dn05'],
#  '粒': ['Bb02', 'Bh13', 'Dn08'],
#  '豆子': ['Bb02', 'Bh06'],
#  '堆': ['Bb03', 'Dn08', 'Fa13', 'Id09'],
#  '垛': ['Bb03', 'Fa13'],
#  '簇': ['Bb03', 'Dn08'],
#  '把': ['Bb03',
#   'Bc04',
#   'Bh12',
#   'Bo25',
#   'Dn05',
#   'Dn08',
#   'Dn09',
#   'Ed60',
#   'Fa04',
#   'Fa06',
#   'Hc10',
#   'Id21',
#   'Kb03'],
#  '把子': ['Bb03', 'Bc04', 'Dn08'],
#  '捆': ['Bb03', 'Dn08', 'Fa17'],
#  '束': ['Bb03', 'Dn08', 'Fa17', 'Je08'],
#  '扎': ['Bb03', 'Fa17', 'Fa29', 'Fd08'],
#  '括': ['Bb03', 'Jd06'],
#  '球': ['Bb04', 'Bd03', 'Bp12', 'Cb23'],
#  '团': ['Bb04', 'Br09', 'Di10', 'Dn08', 'Ea13', 'Fa34'],
#  '蛋': ['Bb04', 'Bl05'],
#  '弹': ['Bb04', 'Bo28', 'Hh04'],
#  '珠': ['Bb04', 'Bm16'],
#  '丸': ['Bb04', 'Br13', 'Dn08'],
#  '圆子': ['Bb04', 'Br09'],
#  '弹子': ['Bb04', 'Bp12', 'Bp35'],
#  '珠子': ['Bb04', 'Bm16'],
#  '轮': ['Bb04', 'Bo22', 'Bo25'],
#  '饼': ['Bb04', 'Br09'],
#  '片': ['Bb04', 'Dn08', 'Eb01', 'Eb02', 'Fa27'],
#  '片子': ['Bb04', 'Bp15', 'Bp18'],
#  '板': ['Bb04', 'Bg07', 'Bm07', 'Bp13', 'Eb10', 'Ee16'],
#  '皮': ['Bb04', 'Bc02', 'Bk10', 'Bm13', 'Bm14', 'Ee09'],
#  '箔': ['Bb04', 'Bo07'],
#  '衣': ['Bb04', 'Bk15', 'Bq03', 'Fa18'],
#  '筒': ['Bb04', 'Bc03', 'Bp11'],
#  '管': ['Bb04', 'Bm07', 'Dn08', 'Hc02', 'Hc09', 'Hg04', 'Ka15', 'Kb03', 'Kc10'],
#  '杆': ['Bb04', 'Bc04', 'Dn08'],
#  '管子': ['Bb04', 'Bm07'],
#  '洞': ['Bb04', 'Cb22', 'Dn04'],
#  '棒': ['Bb05', 'Bo13', 'Eb10', 'Ed03'],
#  '鞭': ['Bb05', 'Bo26', 'Bp36', 'Fa01'],
#  '尺': ['Bb05', 'Bk08', 'Bo18'],
#  '条': ['Bb05', 'Bh10', 'Db07', 'Dk15', 'Dn08', 'Ea01'],
#  '筋': ['Bb05', 'Bk16'],
#  '钩': ['Bb05', 'Dg06'],
#  '网': ['Bb06', 'Dd06', 'Hd26'],
#  '络': ['Bb06', 'Fa17'],
#  '纱': ['Bb06', 'Bm12'],
#  '波': ['Bb06', 'Bg02', 'Da01'],
#  '浪': ['Bb06', 'Bg02', 'Ee11', 'Ee43'],
#  '脉': ['Bb06', 'Bk16'],
#  '顶': ['Bc01',
#   'Dd13',
#   'Fa05',
#   'He04',
#   'Hi42',
#   'Hj24',
#   'Hj58',
#   'Jb01',
#   'Ka02',
#   'Kb02'],
#  '颠': ['Bc01', 'Bk02', 'Fb01', 'Id14'],
#  '峰': ['Bc01', 'Be04', 'Dn08'],
#  '冠': ['Bc01', 'Bq05', 'Dn04', 'Fa18', 'Je05'],
#  '梢头': ['Bc01', 'Bh10'],
#  '端': ['Bc01', 'Db04', 'Dd05', 'Fa04'],
#  '头': ['Bc01', 'Bk02', 'Ca07', 'Cb03', 'Dn04', 'Dn05', 'Dn08'],
#  '嘴': ['Bc01', 'Bc05', 'Bk04'],
#  '尖': ['Bc01', 'Ea10', 'Eb16', 'Ed15'],
#  '终端': ['Bc01', 'Dd13'],
#  '底': ['Bc01', 'Ca09', 'Cb03', 'Da21', 'Dk19', 'Ed61', 'Kd01'],
#  '根': ['Bc01', 'Bh11', 'Db02', 'Dn03', 'Dn08', 'Ka06'],
#  '脚': ['Bc01', 'Bc05', 'Bk08', 'Cb03'],
#  '末尾': ['Bc01', 'Ca09', 'Cb04', 'Da06'],
#  '末梢': ['Bc01', 'Ca09', 'Da06'],
#  '尾': ['Bc01', 'Bk09', 'Cb04', 'Dn08'],
#  '尾子': ['Bc01', 'Da06', 'Dn03'],
#  '屁股': ['Bc01', 'Bk07'],
#  '边': ['Bc02', 'Cb06', 'Dd13'],
#  '沿': ['Bc02', 'Be03', 'Cb06', 'Hj41', 'Ie01', 'Kb02'],
#  '缘': ['Bc02', 'Db10', 'Kb02', 'Kc09'],
#  '角': ['Bc02', 'Bk09', 'Bp13', 'Cb11', 'Cb24', 'Hh07'],
#  '犄角': ['Bc02', 'Bk09', 'Cb24', 'Hb09'],
#  '脸': ['Bc02', 'Bk02', 'Da26'],
#  '表': ['Bc02', 'Bo18', 'Bp18', 'Bp31', 'Dd08', 'Dk14', 'Dk18', 'Ed58', 'Hi14'],
#  '表面': ['Bc02', 'Bp31', 'Dd08'],
#  '正': ['Bc02', 'Dn04', 'Ea09', 'Hj66', 'Ka12', 'Ka26'],
#  '正面': ['Bc02', 'Ee42'],
#  '外表': ['Bc02', 'Dd08'],
#  '外边': ['Bc02', 'Cb05', 'Cb15'],
#  '外面': ['Bc02', 'Cb05'],
#  '表皮': ['Bc02', 'Bk10'],
#  '壳': ['Bc02', 'Bk13'],
#  '壳子': ['Bc02', 'Bk13'],
#  '里': ['Bc02', 'Ca06', 'Cb05', 'Cb15', 'Da05'],
#  '背': ['Bc02',
#   'Bk06',
#   'Ef04',
#   'Fa03',
#   'Hg10',
#   'Hi20',
#   'Hi39',
#   'Hj24',
#   'Ib19',
#   'If03',
#   'Kb01'],
#  '阴': ['Bc02', 'Bd02', 'Bk15', 'Cb02', 'Ea10', 'Eb35', 'Ee01', 'Ia02'],
#  '侧': ['Bc02', 'Fd02'],
#  '外围': ['Bc02', 'Cb05'],
#  '脊': ['Bc02', 'Bk06', 'Bk13'],
#  '梁': ['Bc02', 'Bn06'],
#  '脊梁': ['Bc02', 'Bk06'],
#  '干': ['Bc03',
#   'Bh10',
#   'Bo29',
#   'Cb06',
#   'Eb27',
#   'Ed47',
#   'Ed59',
#   'Ee04',
#   'Gb04',
#   'Hc01',
#   'Hj12',
#   'Hn05',
#   'Ib06',
#   'Je01'],
#  '腹': ['Bc03', 'Bk07'],
#  '腔': ['Bc03', 'Bg07', 'Bk05', 'Dn08'],
#  '胆': ['Bc03', 'Bk14', 'De03'],
#  '帮': ['Bc03', 'Dn08', 'Hi36'],
#  '壁': ['Bc03', 'Bn07'],
#  '颈': ['Bc03', 'Bk05'],
#  '脖': ['Bc03', 'Bk05'],
#  '龙骨': ['Bc03', 'Bk13'],
#  '骨': ['Bc03', 'Bk13'],
#  '架': ['Bc03', 'Dn08', 'Hd01', 'Hn02'],
#  '架子': ['Bc03', 'Dc03', 'Dd06', 'De01'],
#  '框': ['Bc03', 'Je08'],
#  '盖': ['Bc04',
#   'Bk13',
#   'Bo05',
#   'Bp34',
#   'Dk05',
#   'Fa14',
#   'Hd01',
#   'Id03',
#   'Jb04',
#   'Ka17',
#   'Kc09'],
#  '盖子': ['Bc04', 'Bk13'],
#  '帽': ['Bc04', 'Bq05'],
#  '塞': ['Bc04', 'Fa11', 'Fa12', 'Fc06'],
#  '梗': ['Bc04', 'Bh10', 'Id04', 'Id20'],
#  '柄': ['Bc04', 'Bh12', 'Di21', 'Hc09'],
#  '托': ['Bc04', 'Bc05', 'Fa04', 'Hi25', 'Hi33'],
#  '襻': ['Bc04', 'Fa17'],
#  '拉手': ['Bc04', 'Fa35'],
#  '扳手': ['Bc04', 'Bo08'],
#  '门': ['Bc05', 'Bn04', 'Di05', 'Di10'],
#  '座': ['Bc05', 'Bd01', 'Cb01', 'Dn08'],
#  '腿': ['Bc05', 'Bk08'],
#  '足': ['Bc05', 'Bk08', 'Ed39', 'Gc02', 'He14'],
#  '翼': ['Bc05', 'Bk09'],
#  '翅': ['Bc05', 'Bk09', 'Br06'],
#  '翅膀': ['Bc05', 'Bk09'],
#  '翅子': ['Bc05', 'Br06'],
#  '挡': ['Bc05', 'Bo03', 'Hi53', 'Id03'],
#  '栅': ['Bc05', 'Bn07'],
#  '心': ['Bc05', 'Bk14', 'Cb04', 'Cb23', 'Df02'],
#  '天地': ['Bd01', 'Dd05'],
#  '星星': ['Bd01', 'Eb01'],
#  '辰': ['Bd01', 'Ca03', 'Ca30'],
#  '宿': ['Bd01', 'Hj01'],
#  '云汉': ['Bd01', 'Cb07'],
#  '牵牛': ['Bd01', 'Bh02'],
#  '斗': ['Bd01', 'Bo18', 'Bp26', 'Ha02', 'Hh07', 'Hi44'],
#  '太阳': ['Bd02', 'Bg03'],
#  '阳': ['Bd02', 'Bk15', 'Cb02', 'Ea10', 'Eb35', 'Ed46'],
#  '日': ['Bd02', 'Ca03', 'Ca23'],
#  '夕阳': ['Bd02', 'Ca17'],
#  '月': ['Bd02', 'Ca21'],
#  '月宫': ['Bd02', 'Dh02'],
#  '蟾宫': ['Bd02', 'Dh02'],
#  '蟾蜍': ['Bd02', 'Bi10'],
#  '新月': ['Bd02', 'Ca21'],
#  '日月': ['Bd02', 'Ca03'],
#  '地': ['Bd03', 'Be01', 'Bn05', 'Bn12', 'Cb07', 'Da21'],
#  '寰宇': ['Bd03', 'Di01'],
#  '陆': ['Be01', 'Dn04'],
#  '洲': ['Be01', 'Be02'],
#  '冲': ['Be01',
#   'Ec11',
#   'Ed15',
#   'Fa21',
#   'Fa24',
#   'Fd08',
#   'Hd08',
#   'Hg03',
#   'Kb01',
#   'Kb07'],
#  '荒地': ['Be01', 'Cb18'],
#  '生地': ['Be01', 'Bh08'],
#  '莽苍': ['Be01', 'Eb20'],
#  '圹': ['Be01', 'Bn22'],
#  '平地': ['Be01', 'Hd17'],
#  '坝子': ['Be01', 'Bn14'],
#  '沙场': ['Be01', 'Cb12'],
#  '一马平川': ['Be01', 'Ea11'],
#  '草地': ['Be01', 'Bn20'],
#  '泽国': ['Be01', 'Cb10'],
#  '荒漠': ['Be01', 'Cb11', 'Ea04'],
#  '坝': ['Be03', 'Bn14'],
#  '滨': ['Be03', 'Cb06', 'Id21'],
#  '山': ['Be04', 'Bo07'],
#  '岩': ['Be04', 'Bm04'],
#  '山陵': ['Be04', 'Bn22'],
#  '峻': ['Be04', 'Ea02', 'Ea12'],
#  '岗': ['Be04', 'Cb28', 'Di15'],
#  '丘': ['Be04', 'Bn22', 'Dn08'],
#  '山头': ['Be04', 'Di10'],
#  '顶峰': ['Be04', 'Dd13'],
#  '巅峰': ['Be04', 'Dd13'],
#  '陬': ['Be04', 'Cb24'],
#  '谷': ['Be04', 'Bh05'],
#  '低谷': ['Be04', 'Da20'],
#  '悬崖峭壁': ['Be04', 'Cb19'],
#  '坡': ['Be04', 'Ea09'],
#  '大洋': ['Be05', 'Dj05'],
#  '水': ['Be05', 'Bg01', 'Dn09'],
#  '水流': ['Be05', 'Bg01'],
#  '长河': ['Be05', 'Da05'],
#  '江湖': ['Be05', 'Di01'],
#  '城池': ['Be05', 'Cb25'],
#  '港': ['Be05', 'Cb26'],
#  '洪流': ['Be05', 'Bg01'],
#  '奔流': ['Be05', 'Id11'],
#  '沟': ['Be05', 'Bn08', 'Bn15'],
#  '沟渠': ['Be05', 'Bn15'],
#  '泥坑': ['Be06', 'Da21'],
#  '泉': ['Be07', 'Dj05'],
#  '玉龙': ['Be07', 'Bf01'],
#  '霈': ['Bf01', 'Ia03'],
#  '疾风暴雨': ['Bf01', 'Bf02'],
#  '雪': ['Bf01', 'Ec04', 'Jd10'],
#  '雪条': ['Bf01', 'Br12'],
#  '凌': ['Bf01', 'Hi58'],
#  '雄风': ['Bf02', 'Da27'],
#  '逆风': ['Bf02', 'Ka25'],
#  '顶风': ['Bf02', 'Ka25'],
#  '狂风暴雨': ['Bf02', 'Da02'],
#  '暴风骤雨': ['Bf02', 'Da02', 'Ed15', 'Ia03'],
#  '凄风苦雨': ['Bf02', 'Da08', 'Ia03'],
#  '云': ['Bf02', 'Hi12'],
#  '彤云': ['Bf02', 'Bf04'],
#  '露': ['Bf03', 'Hi14', 'Id03', 'If23', 'Jd06'],
#  '霓': ['Bf04', 'Gb04'],
#  '烟': ['Bf05', 'Br14', 'Id17'],
#  '霹雳': ['Bf06', 'Ia05'],
#  '闪电': ['Bf06', 'Ia05'],
#  '电': ['Bf06', 'Bg04', 'Dk16', 'Hi11', 'If18'],
#  '潮': ['Bf07', 'Da02', 'Eb27', 'Ed03'],
#  '溜': ['Bg01', 'Dn08', 'Fb01', 'Fc04', 'Fd05', 'Hj38'],
#  '白煤': ['Bg01', 'Bm08'],
#  '深渊': ['Bg01', 'Da21'],
#  '汤': ['Bg01', 'Br13'],
#  '浆': ['Bg01', 'Fa21'],
#  '糊': ['Bg01', 'Fa20'],
#  '泡': ['Bg02', 'Eb09', 'Fa24', 'Hj03', 'Id11'],
#  '浪头': ['Bg02', 'Da20'],
#  '涛': ['Bg02', 'Bg07'],
#  '惊涛骇浪': ['Bg02', 'Da02', 'Ia06'],
#  '涡流': ['Bg02', 'Da02'],
#  '灯火': ['Bg03', 'Bp01'],
#  '烟火': ['Bg03', 'Bp36', 'Br03'],
#  '焰火': ['Bg03', 'Bp36'],
#  '烽火': ['Bg03', 'Di11'],
#  '烽烟': ['Bg03', 'Di11'],
#  '狼烟': ['Bg03', 'Di11'],
#  '兵燹': ['Bg03', 'Da09', 'Di11'],
#  '战火': ['Bg03', 'Di11'],
#  '烟尘': ['Bg03', 'Bg08', 'Di11'],
#  '光': ['Bg03', 'Da13', 'Dn01', 'Eb33', 'Ed26', 'Id03', 'Ka06', 'Ka07'],
#  '光明': ['Bg03', 'Eb18', 'Ed23'],
#  '光耀': ['Bg03', 'Ed24'],
#  '光辉': ['Bg03', 'Ed20'],
#  '灯光': ['Bg03', 'Dn01'],
#  '影': ['Bg03', 'Dk29', 'Dk32', 'Hg11', 'Hj38'],
#  '气': ['Bg05', 'Bg06', 'De01', 'De03', 'Df01', 'Df06', 'Df11', 'Ga03', 'Hi58'],
#  '空气': ['Bg05', 'Da21'],
#  '大气': ['Bg05', 'Ee35'],
#  '颜色': ['Bg06', 'Bm11'],
#  '色': ['Bg06', 'Dc02', 'Dc04', 'Dd06', 'Dd12'],
#  '彩': ['Bg06', 'Bq02', 'Ec06'],
#  '色彩': ['Bg06', 'Dk08'],
#  '本色': ['Bg06', 'Dd08'],
#  '气味': ['Bg06', 'Df12'],
#  '味': ['Bg06', 'Dn08'],
#  '味道': ['Bg06', 'Df04', 'Dk10'],
#  '滋味': ['Bg06', 'Df04'],
#  '回味': ['Bg06', 'Gb08'],
#  '动静': ['Bg07', 'Da21'],
#  '声': ['Bg07', 'Da26'],
#  '音': ['Bg07', 'Da19', 'Dk10'],
#  '响': ['Bg07', 'Eb16', 'Ia08'],
#  '乐': ['Bg07', 'Dk28', 'Ga01', 'Ic01'],
#  '回音': ['Bg07', 'Dk11', 'Dk16'],
#  '国语': ['Bg07', 'Dk06'],
#  '字': ['Bg07', 'Bp19', 'Dd15', 'Dk05', 'Dk06', 'Hj51'],
#  '话音': ['Bg07', 'Dk10'],
#  '叮当': ['Bg07', 'Ia08'],
#  '声调': ['Bg07', 'Dk29'],
#  '腔调': ['Bg07', 'Dk29'],
#  '调': ['Bg07', 'Hc03'],
#  '调子': ['Bg07', 'Dk08'],
#  '拍子': ['Bg07', 'Bp12'],
#  '板眼': ['Bg07', 'Db07'],
#  '灰': ['Bg08', 'Bm05', 'Ec04'],
#  '尘': ['Bg08', 'Di01'],
#  '污': ['Bg08', 'Ef12'],
#  '垢': ['Bg08', 'Da13'],
#  '污秽': ['Bg08', 'Ef12'],
#  '污浊': ['Bg08', 'Ef12'],
#  '污点': ['Bg08', 'Da13'],
#  '龌龊': ['Bg08', 'Ee42', 'Ef12'],
#  '肮脏': ['Bg08', 'Ef12'],
#  '皴': ['Bg08', 'Id06'],
#  '皱': ['Bg09', 'Ea08'],
#  '螺纹': ['Bg09', 'Bo03'],
#  '印子': ['Bg09', 'Dj04'],
#  '辙': ['Bg09', 'Db09'],
#  '踪迹': ['Bg09', 'Da23'],
#  '行踪': ['Bg09', 'Da23'],
#  ...}

# %% [markdown]
# ## HIT Corpus processing

# %%
import re

corpus = open(r'./data/Sense_POS.txt', 'r', encoding='utf-8')

syn_lines = []
# The upper bound for synonyms which can appear in one sentence.
syn_count_bound = 15

for line in corpus:
    # Skip the empty line
    if (line == ''):
        continue
    # Clean the word's hierachy, e.g.
    # [香港/ns/Cb25 中华/nz/Di02 总商会/n/Di23]nt 
    # transferred to
    # 香港/ns/Cb25 中华/nz/Di02 总商会/n/Di23
    line = re.sub(r'\]\w*', '', line.strip().replace('[', ''))
    # Split by [space]
    sep = line.split(' ')
    # Iterate through the words to check if the sentence 
    # containing only one synonym. If so, mark the 
    # corrsponding index and generate two line for traning.
    syn_count = 0
    i, index = 0, []
    for word in sep:
        word_text, _, word_sense = word.split('/')
        if (word_text in syn_dict and word_sense in syn_dict[word_text]):
            syn_count = syn_count + 1
            index.append(i)
        i = i + 1
    if (len(index) == 0 or syn_count > syn_count_bound):
        continue
    tmp = []
    for w in sep:
        tmp_sep = w.split('/')
        tmp.append((tmp_sep[0], tmp_sep[1], tmp_sep[2]))
    syn_lines.append((index, tmp))

corpus.close()

# Format for `syn_lines`
# 1. `syn_lines`是一个列表，每个元素描述了句子中多义词的位置
# 2. 每一个元素是一个tuple，tuple的前一个元素是一个列表，列表中的每一个元素是一个数字，代表同义词
# 在后一个元素中的下标位置，后一个元素是句子按照词语分割形成的列表

# %%
syn_lines[0]
# Out:
# ([2, 3, 4, 8, 9, 14],
#  [('迈向', 'v', 'Fb01'),
#   ('充满', 'v', 'Jd06'),
#   ('希望', 'n', 'Df08'),
#   ('的', 'u', 'Kd01'),
#   ('新', 'a', 'Eb28'),
#   ('世纪', 'n', 'Ca18'),
#   ('——', 'wp', '-1'),
#   ('一九九八年', 'nt', '-1'),
#   ('新年', 'nt', 'Ca25'),
#   ('讲话', 'n', 'Dk11'),
#   ('（', 'wp', '-1'),
#   ('附', 'v', '-1'),
#   ('图片', 'n', 'Dk18'),
#   ('１', 'm', '-1'),
#   ('张', 'q', 'Dn08'),
#   ('）', 'wp', '-1')])

# %% [markdown]
# ## Generate the training set

# %%
import random


def random_pick(collection: list) -> str :
    return collection[random.randint(0, len(collection) - 1)]

# Exclusively picking another item from list
def random_pick_ex(collec: list, ex_item: str) -> str :
    offset = random.randint(1, len(collec) - 1)
    ex_index = collec.index(ex_item)
    return collec[(ex_index + offset) % len(collec)]

# Generating the training set
gen_corpus_list = []
for sentence in syn_lines[:738]:
    index = random_pick(sentence[0])
    word, _, sense = sentence[1][index]
    senses = syn_dict[word]
    # Get another sense
    sub_sense = random_pick_ex(senses, sense)
    # Get another word for substitution
    sub_words = syn_sense[sub_sense]
    sub_word = random_pick_ex(sub_words, word)

    positive_line = "%d %s\n" % (1, ' '.join(w[0] for w in sentence[1]))
    tmp_sentence = [w[0] for w in sentence[1]]
    tmp_sentence[index] = sub_word
    negative_line = "%d %s\n" % (0, ' '.join(tmp_sentence))
    gen_corpus_list.extend([positive_line, negative_line])
gen_corpus = open(r'./data/gen_corpus.plain.utf8.txt', 'w', encoding='utf-8')
# random.shuffle(gen_corpus_list)
for line in gen_corpus_list:
    gen_corpus.write(line)
gen_corpus.close()

# Generating the validation set
gen_valid_list = []
for sentence in syn_lines[738:]:
    pos_line = "%d %s\n" % (1, ' '.join([w[0] for w in sentence[1]]))
    for index in sentence[0]:
        word, _, sense = sentence[1][index]
        senses = syn_dict[word]
        tmp_valid_list = [pos_line]
        for sub_sense in senses:
            if (sub_sense == sense):
                continue
            sub_word = random_pick_ex(syn_sense[sub_sense], word)
            tmp_sentence = [w[0] for w in sentence[1]]
            tmp_sentence[index] = sub_word
            neg_line = "%d %s\n" % (0, ' '.join(tmp_sentence))
            tmp_valid_list.append(neg_line)
        gen_valid_list.append(tmp_valid_list)

gen_valid = open(r'./data/gen_valid.plain.utf8.txt', 'w', encoding='utf-8')
for lines in gen_valid_list:
    for line in lines:
        gen_valid.write(line)
    gen_valid.write('$\n')
gen_valid.close()

# %%
f = open(r'./data/gen_corpus.plain.utf8.txt', 'r', encoding='utf-8')
for l1 in f:
    l2 = f.readline()
    s1 = ''.join(l1.split(' ')[1:])
    s2 = ''.join(l2.split(' ')[1:])
    if (s1 == s2) :
        print("%s\n%s\n" % (s1, s2))
f.close()

# %% [markdown]
# ## Author
# Coded by [mine268](https://github.com/mine268).
